# %% [markdown]
# # *튤립 판매 데이터 분석 2017~2018년

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 82DC-41C1
#
#  C:\Users\ifupk\Python\PandasProject 디렉터리
#
# 2021-12-18  오후 11:56    <DIR>          .
# 2021-12-18  오후 11:56    <DIR>          ..
# 2021-12-18  오후 11:56    <DIR>          .ipynb_checkpoints
# 2021-12-18  오후 11:56            20,949 Matplotlib한글깨짐.ipynb
# 2021-12-18  오후 11:44                17 README.md
# 2021-12-18  오후 11:44           631,390 seed_sales_data.csv
# 2021-12-18  오후 11:44             1,058 ShoppingMallSalesData.ipynb
# 2021-12-18  오후 11:44            19,126 tu_1718.csv
# 2021-12-18  오후 11:44           298,653 코리아팜_판매데이터_워드클라우드.ipynb
# 2021-12-18  오후 11:44         2,413,705 코리아팜판매데이터분석14~18년.ipynb
# 2021-12-18  오후 11:44            81,937 튤립판매데이터분석_17~18년.ipynb
#                8개 파일           3,466,835 바이트
#                3개 디렉터리  81,102,368,768 바이트 남음

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.style.use('ggplot')

# mpl.rcParams['axes.unicode_minus'] = False # -마이너스 폰트 깨짐 방지(전역 변수 설정함)
# %matplotlib inline

# %% [markdown]
# ## 4. 폰트를 설정해 주기에 앞서 설치 된 matplotlib의 버전과 위치정보를 가져옵니다.

# %%
print('버전: ', mpl.__version__)
print('설치 위치:', mpl.__file__)
print('설정 위치: ', mpl.get_configdir())
print('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.5.0
# 설치 위치: C:\Anaconda3\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\ifupk\.matplotlib
# 캐시 위치:  C:\Users\ifupk\.matplotlib

# %% [markdown]
# ## 5. matplotlib의 위치 정보를 알았으니 터미널을 이용해 해당 위치로 가봅니다.

# %%
print('설정파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정파일 위치:  C:\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# ## 6. 설치 된 폰트를 찍어 봅니다.

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
# ttf 폰 전체 갯수
print(len(font_list))
# Out:
# 452

# %%
#시스템 폰에서 읽어온 리스트에서 상위 10개만 출력
font_list[:10]
# Out:
# ['C:\\Windows\\Fonts\\MyriadPro-Cond.otf',
#  'C:\\Windows\\Fonts\\SourceCodePro-LightIt.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareEB.ttf',
#  'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  'C:\\Windows\\Fonts\\MinionPro-MediumIt.otf',
#  'C:\\Windows\\Fonts\\LFAX.TTF',
#  'C:\\Windows\\Fonts\\NanumGothicExtraBold.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSB.TTF',
#  'C:\\Windows\\Fonts\\seguihis.ttf']

# %%
f = [f.name for f in fm.fontManager.ttflist]
print(len(font_list))
# 10개의 폰트명 만 출력
f[:10]
# Out:
# 452
# ['cmr10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXSizeFiveSym']

# %%
[f.name for f in fm.fontManager.ttflist if '' in f.name]
# Out:
# ['cmr10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'DejaVu Serif',
#  'DejaVu Sans Display',
#  'cmsy10',
#  'STIXSizeThreeSym',
#  'STIXSizeThreeSym',
#  'cmtt10',
#  'DejaVu Sans',
#  'cmb10',
#  'STIXNonUnicode',
#  'cmex10',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmmi10',
#  'STIXGeneral',
#  'cmss10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'Microsoft PhagsPa',
#  'HYsnrL',
#  'Book Antiqua',
#  'Niagara Solid',
#  'Sitka Small',
#  'D2Coding',
#  'Lucida Bright',
#  'HYgsrB',
#  'Myriad Pro',
#  'Blackoak Std',
#  'MV Boli',
#  'Arial',
#  'Verdana',
#  'HYPost-Light',
#  'Yu Gothic',
#  'HYSinMyeongJo-Medium',
#  'Franklin Gothic Medium',
#  'Marlett',
#  'Sitka Small',
#  'Lucida Handwriting',
#  'HYPMokGak-Bold',
#  'Lucida Sans Unicode',
#  'Trebuchet MS',
#  'HYGothic-Extra',
#  'Onyx',
#  'Minion Pro',
#  'HYMyeongJo-Extra',
#  'Myriad Pro',
#  'Segoe UI',
#  'HYkanM',
#  'Segoe Script',
#  'New Gulim',
#  'Minion Pro',
#  'Kozuka Mincho Pro',
#  'D2Coding ligature',
#  'Segoe UI',
#  'Chiller',
#  'Poplar Std',
#  'Gabriola',
#  'Arial',
#  'Segoe UI',
#  'Adobe Caslon Pro',
#  'Palatino Linotype',
#  'BM KIRANGHAERANG',
#  'Kozuka Gothic Pro',
#  'Lucida Fax',
#  'OCR A Std',
#  'Kozuka Gothic Pro',
#  'Baskerville Old Face',
#  'Ebrima',
#  'Myriad Pro',
#  'HYgtrE',
#  'Minion Pro',
#  'Brush Script Std',
#  'Prestige Elite Std',
#  'Birch Std',
#  'HYhaeseo',
#  'HYdnkB',
#  'Brush Script MT',
#  'Leelawadee UI',
#  'Myriad Pro',
#  'Tahoma',
#  'Corbel',
#  'Mesquite Std',
#  'D2Coding',
#  'Pyunji R',
#  'Tekton Pro',
#  'Nueva Std',
#  'Cambria',
#  'Eccentric Std',
#  'High Tower Text',
#  'Garamond',
#  'Nueva Std',
#  'Gadugi',
#  'Courier New',
#  'Parchment',
#  'Charlemagne Std',
#  'Calibri',
#  'Microsoft JhengHei',
#  'Nanum Pen Script',
#  'Kozuka Gothic Pro',
#  'Bell Gothic Std',
#  'Courier New',
#  'Minion Pro',
#  'Cooper Black',
#  'BM EULJIRO TTF',
#  'Malgun Gothic',
#  'MS Reference Sans Serif',
#  'Tekton Pro',
#  'HYsupM',
#  'Georgia',
#  'BM Euljiro 10 years later',
#  'Comic Sans MS',
#  'Letter Gothic Std',
#  'Trebuchet MS',
#  'Times New Roman',
#  'Myriad Pro',
#  'Kristen ITC',
#  'Garamond',
#  'Impact',
#  'NanumBarunpen',
#  'Tempus Sans ITC',
#  'Times New Roman',
#  'Bell MT',
#  'Wingdings',
#  'Century',
#  'HYHeadLine-Medium',
#  'Poor Richard',
#  'Comic Sans MS',
#  'Book Antiqua',
#  'Monotype Corsiva',
#  'HYPost-Medium',
#  'Adobe Caslon Pro',
#  'NanumGothic',
#  'Cafe24 Shiningstar',
#  'Nanum Brush Script',
#  'Minion Pro',
#  'Microsoft YaHei',
#  'HYGungSo-Bold',
#  'NanumGothicCoding',
#  'NanumSquareRound',
#  'Kozuka Mincho Pro',
#  'Playbill',
#  'Vladimir Script',
#  'Nirmala UI',
#  'Chaparral Pro',
#  'Berlin Sans FB',
#  'Arial',
#  'Kozuka Mincho Pro',
#  'Franklin Gothic Medium',
#  'Cooper Std',
#  'Harlow Solid Italic',
#  'SimSun-ExtB',
#  'Lithos Pro',
#  'NanumGothic',
#  'NanumSquare',
#  'BM YEONSUNG',
#  'HYdnkM',
#  'Lucida Bright',
#  'Britannic Bold',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'Mongolian Baiti',
#  'Candara',
#  'Microsoft YaHei',
#  'Cafe24 Ohsquare air',
#  'Adobe Caslon Pro',
#  'Microsoft Tai Le',
#  'Myriad Pro',
#  'Ravie',
#  'Symbol',
#  'Gulim',
#  'Leelawadee UI',
#  'Orator Std',
#  'HYnamM',
#  'Bell MT',
#  'HYtbrB',
#  'HYGothic-Medium',
#  'Segoe Print',
#  'Cambria',
#  'Cafe24 Danjunghae',
#  'Lithos Pro',
#  'Wide Latin',
#  'Verdana',
#  'Constantia',
#  'Giddyup Std',
#  'Algerian',
#  'Microsoft Tai Le',
#  'Cambria',
#  'Showcard Gothic',
#  'Segoe UI',
#  'Letter Gothic Std',
#  'Tekton Pro',
#  'Verdana',
#  'Wingdings 2',
#  'NanumBarunGothic',
#  'Microsoft JhengHei',
#  'Sylfaen',
#  'Cambria',
#  'Lucida Fax',
#  'Trajan Pro',
#  'HYsupB',
#  'Hobo Std',
#  'HYShortSamul-Medium',
#  'Adobe Caslon Pro',
#  'Georgia',
#  'HyhwpEQ',
#  'HYsanB',
#  'Yet R',
#  'Constantia',
#  'Kozuka Mincho Pro',
#  'Malgun Gothic',
#  'Chaparral Pro',
#  'Trebuchet MS',
#  'Corbel',
#  'Calibri',
#  'Microsoft Himalaya',
#  'Viner Hand ITC',
#  'Haansoft Batang',
#  'ahn2006-B',
#  'Broadway',
#  'HYbdaM',
#  'Modern No. 20',
#  'HYnamB',
#  'Berlin Sans FB',
#  'NanumBarunGothic',
#  'ahn2006-M',
#  'Comic Sans MS',
#  'MingLiU-ExtB',
#  'Microsoft New Tai Lue',
#  'NanumGothic',
#  'Segoe UI',
#  'Footlight MT Light',
#  'Century Gothic',
#  'Bookman Old Style',
#  'Times New Roman',
#  'Segoe UI',
#  'Microsoft Yi Baiti',
#  'Myriad Pro',
#  'Palatino Linotype',
#  'Myanmar Text',
#  'BM HANNA 11yrs old',
#  'Californian FB',
#  'Calibri',
#  'Stencil',
#  'Courier New',
#  'Calibri',
#  'Consolas',
#  'Microsoft YaHei',
#  'Webdings',
#  'NanumBarunGothic',
#  'Orator Std',
#  'ahn2006-L',
#  'Microsoft New Tai Lue',
#  'Freestyle Script',
#  'NanumGothicCoding',
#  'Juice ITC',
#  'Consolas',
#  'Courier New',
#  'Nirmala UI',
#  'HYwulB',
#  'Times New Roman',
#  'Bodoni MT',
#  'Georgia',
#  'Adobe Song Std',
#  'Rosewood Std',
#  'Sitka Small',
#  'MoeumT R',
#  'Arial',
#  'Minion Pro',
#  'NanumMyeongjo',
#  'Bookshelf Symbol 7',
#  'Cafe24 Oneprettynight',
#  'MS Gothic',
#  'Ink Free',
#  'Headline R',
#  'Adobe Heiti Std',
#  'MS Mincho',
#  'Kozuka Gothic Pro',
#  'Cooper Std',
#  'Cafe24 Ssurround',
#  'HYnamL',
#  'Palatino Linotype',
#  'NanumMyeongjo',
#  'Arial',
#  'Adobe Ming Std',
#  'Microsoft PhagsPa',
#  'Minion Pro',
#  'Adobe Garamond Pro',
#  'Segoe UI',
#  'NanumSquareRound',
#  'Myanmar Text',
#  'Garamond',
#  'NanumGothic',
#  'Chaparral Pro',
#  'Verdana',
#  'Californian FB',
#  'Cafe24 Syongsyong',
#  'Century Gothic',
#  'Informal Roman',
#  'Book Antiqua',
#  'Georgia',
#  'NanumSquare',
#  'D2Coding',
#  'Corbel',
#  'Candara',
#  'Century Gothic',
#  'HYwulM',
#  'Adobe Caslon Pro',
#  'Microsoft JhengHei',
#  'Palatino Linotype',
#  'Candara',
#  'Tekton Pro',
#  'Segoe UI Historic',
#  'Consolas',
#  'Arial',
#  'Arial',
#  'Cafe24 Ssukssuk ',
#  'Segoe UI Symbol',
#  'HoloLens MDL2 Assets',
#  'Arial',
#  'Adobe Caslon Pro',
#  'Segoe Script',
#  'Adobe Garamond Pro',
#  'Bernard MT Condensed',
#  'HYbdaL',
#  'Letter Gothic Std',
#  'Myriad Pro',
#  'HYmjrE',
#  'HYcysM',
#  'HYbsrB',
#  'Bell Gothic Std',
#  'Minion Pro',
#  'BM JUA_TTF',
#  'Kozuka Gothic Pro',
#  'NanumSquareRound',
#  'SimSun',
#  'Kunstler Script',
#  'Candara',
#  'Cafe24 Ohsquare',
#  'Nirmala UI',
#  'Lucida Calligraphy',
#  'Snap ITC',
#  'Bookman Old Style',
#  'Corbel',
#  'Trebuchet MS',
#  'Berlin Sans FB Demi',
#  'Kozuka Gothic Pro',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Vivaldi',
#  'Nueva Std',
#  'Javanese Text',
#  'Yu Gothic',
#  'Calibri',
#  'Microsoft Sans Serif',
#  'Arial Unicode MS',
#  'Matura MT Script Capitals',
#  'FZSong_Superfont',
#  'Bookman Old Style',
#  'Yu Gothic',
#  'Segoe UI Emoji',
#  'BM DoHyeon',
#  'Wingdings 3',
#  'Malgun Gothic',
#  'Californian FB',
#  'Corbel',
#  'Letter Gothic Std',
#  'Batang',
#  'Minion Pro',
#  'Adobe Kaiti Std',
#  'Colonna MT',
#  'NanumBarunpen',
#  'Lucida Bright',
#  'Bauhaus 93',
#  'High Tower Text',
#  'Old English Text MT',
#  'HYmprL',
#  'HYporM',
#  'Gadugi',
#  'Leelawadee UI',
#  'Lucida Fax',
#  'HYkanB',
#  'Adobe Fangsong Std',
#  'Constantia',
#  'Cafe24 Dongdong',
#  'Haansoft Dotum',
#  'Lucida Fax',
#  'Nueva Std',
#  'BM HANNA Air',
#  'Candara',
#  'Segoe UI',
#  'Adobe Myungjo Std',
#  'Arial',
#  'Adobe Garamond Pro',
#  'Harrington',
#  'NanumBarunGothic',
#  'Century Gothic',
#  'Centaur',
#  'Cafe24 Simplehae',
#  'Segoe MDL2 Assets',
#  'Ebrima',
#  'Myriad Pro',
#  'Ami R',
#  'NanumSquareRound',
#  'Mistral',
#  'HYgprM',
#  'Magneto',
#  'Yu Gothic',
#  'Book Antiqua',
#  'HYGraphic-Medium',
#  'Jokerman',
#  'Calibri',
#  'Cafe24 Dangdanghae',
#  'NanumSquare',
#  'Consolas',
#  'Myriad Pro',
#  'Chaparral Pro',
#  'Segoe UI',
#  'Corbel',
#  'Segoe Print',
#  'Candara',
#  'Minion Pro',
#  'Bell MT',
#  'Sitka Small',
#  'Lucida Bright',
#  'Magic R',
#  'BM HANNA Pro',
#  'Constantia',
#  'Segoe UI',
#  'Stencil Std',
#  'MS Reference Specialty',
#  'Trajan Pro',
#  'Niagara Engraved',
#  'Segoe UI',
#  'Kozuka Mincho Pro',
#  'Kozuka Mincho Pro',
#  'Bahnschrift',
#  'Lucida Console',
#  'Tahoma',
#  'Adobe Garamond Pro',
#  'Bookman Old Style']

# %%
[f.name for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# ['Nanum Pen Script',
#  'NanumBarunpen',
#  'NanumGothic',
#  'Nanum Brush Script',
#  'NanumGothicCoding',
#  'NanumSquareRound',
#  'NanumGothic',
#  'NanumSquare',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumGothic',
#  'NanumBarunGothic',
#  'NanumGothicCoding',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumSquareRound',
#  'NanumGothic',
#  'NanumSquare',
#  'NanumSquareRound',
#  'NanumBarunpen',
#  'NanumBarunGothic',
#  'NanumSquareRound',
#  'NanumSquare']

# %%
#shop_1718 = pd.read_csv('tu_1718.csv', encoding='cp949') #UTF-8 error 시
#shop_1718.head()

df = pd.read_csv('tu_1718.csv', encoding='cp949')
df.shape
# Out:
# (539, 4)

# %%
df.head()
# Out:
#         날짜   업체명    상품명  주문수
# 0  11월 07일  엔앤케이    아펠톤    5
# 1  11월 07일  엔앤케이  골든아펠톤   40
# 2  11월 07일  엔앤케이    아펠톤   40
# 3  11월 07일  엔앤케이  린반더마크    5
# 4  11월 07일  엔앤케이   네그리타    5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      539 non-null    object
#  1   업체명     539 non-null    object
#  2   상품명     539 non-null    object
#  3   주문수     539 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 17.0+ KB

# %%
df.describe()
# Out:
#               주문수
# count  539.000000
# mean    15.602968
# std     43.426198
# min      0.000000
# 25%      5.000000
# 50%      5.000000
# 75%     10.000000
# max    500.000000

# %%
df['업체명'].value_counts()
# Out:
# 유비큐솔루션    363
# 엔앤케이       83
# 씨앗나래       61
# 그린팜        32
# Name: 업체명, dtype: int64

# %%
df['상품명'].value_counts()
# Out:
# 린반더마크    121
# 키스넬리스    117
# 다이너스티    113
# 골든아펠톤     80
# 아펠톤       63
# 네그리타      45
# Name: 상품명, dtype: int64

# %%
figure,(ax1, ax2) = plt.subplots(1, 2)
figure.set_size_inches(20,10)
# 상품별 주문수 1
sns.countplot(data=df, y="상품명", ax=ax1)
# 상품별 주문수 2
sns.barplot(data=df, x="상품명", y="주문수", ax=ax2)
# Out:
# <AxesSubplot:xlabel='상품명', ylabel='주문수'>

# %%
plt.figure(figsize=(20,5))
plt.title('날짜별 주문건수')
plt.xticks(rotation=60, ha='right')
sns.countplot(data=df, x="날짜")
# Out:
# <AxesSubplot:title={'center':'날짜별 주문건수'}, xlabel='날짜', ylabel='count'>

# %%
figure,(ax1) = plt.subplots(1)
figure.set_size_inches(10,5)
#업체별 주문수
sns.countplot(data=df, y="업체명", ax=ax1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='업체명'>

# %% [markdown]
# ## 우리 신입 직원이 추가한 부분입니다.
